# %%
#1. Efectuar una limpieza del dataset provisto. Particularmente, deberá diseñar estrategias para lidiar con los datos perdidos en ciertas variables.

#2. Realizar un análisis descriptivo de las principales variables.

#3. Crear nuevas columnas a partir de las características dadas que puedan tener valor predictivo.

# %%
#Importamos librerias requeridas
import pandas as pd
import numpy as np
import datetime
from os import listdir
from os.path import isfile, join
import glob
import re

# %%
#Creamos un data frame en base al csv de Properati.
df = pd.read_csv("properatti.csv")

# %%
#Verificamos la integridad de los datos.

# %%
df.dtypes
# Out:
# Unnamed: 0                      int64
# operation                      object
# property_type                  object
# place_name                     object
# place_with_parent_names        object
# country_name                   object
# state_name                     object
# geonames_id                   float64
# lat-lon                        object
# lat                           float64
# lon                           float64
# price                         float64
# currency                       object
# price_aprox_local_currency    float64
# price_aprox_usd               float64
# surface_total_in_m2           float64
# surface_covered_in_m2         float64
# price_usd_per_m2              float64
# price_per_m2                  float64
# floor                         float64
# rooms                         float64
# expenses                      float64
# properati_url                  object
# description                    object
# title                          object
# ...

# %%
df.head()
# Out:
#    Unnamed: 0 operation property_type place_name  \
# 0           0      sell            PH  Mataderos
# 1           1      sell     apartment   La Plata
# 2           2      sell     apartment  Mataderos
# 3           3      sell            PH    Liniers
# 4           4      sell     apartment     Centro
#
#                              place_with_parent_names country_name  \
# 0              |Argentina|Capital Federal|Mataderos|    Argentina
# 1        |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
# 2              |Argentina|Capital Federal|Mataderos|    Argentina
# 3                |Argentina|Capital Federal|Liniers|    Argentina
# 4  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
#
#                      state_name  geonames_id                  lat-lon  \
# 0               Capital Federal    3430787.0  -34.6618237,-58.5088387
# 1        Bs.As. G.B.A. Zona Sur    3432039.0  -34.9038831,-57.9643295
# ...

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'operation',
#  'property_type',
#  'place_name',
#  'place_with_parent_names',
#  'country_name',
#  'state_name',
#  'geonames_id',
#  'lat-lon',
#  'lat',
#  'lon',
#  'price',
#  'currency',
#  'price_aprox_local_currency',
#  'price_aprox_usd',
#  'surface_total_in_m2',
#  'surface_covered_in_m2',
#  'price_usd_per_m2',
#  'price_per_m2',
#  'floor',
#  'rooms',
#  'expenses',
#  'properati_url',
#  'description',
#  'title',
#  'image_thumbnail']

# %%
df.isna().any()
# Out:
# Unnamed: 0                    False
# operation                     False
# property_type                 False
# place_name                     True
# place_with_parent_names       False
# country_name                  False
# state_name                    False
# geonames_id                    True
# lat-lon                        True
# lat                            True
# lon                            True
# price                          True
# currency                       True
# price_aprox_local_currency     True
# price_aprox_usd                True
# surface_total_in_m2            True
# surface_covered_in_m2          True
# price_usd_per_m2               True
# price_per_m2                   True
# floor                          True
# rooms                          True
# expenses                       True
# properati_url                 False
# description                    True
# title                         False
# image_thumbnail                True
# ...

# %%
#Correccion de la ubicacion

# %%
#Hacemos un split de la columna 'place with parent names' para corregir principalmente place_name.
df[['id','Country','State','Municipality','Localidad','Neighbourhood','Atributo6']] = df['place_with_parent_names'].str.split('|', expand=True)

# %%
#Revisamos que valores no nulos hay dentro de la columna Atributo6.
df.loc[df['Atributo6'].notnull()]
# Out:
#         Unnamed: 0 operation property_type                 place_name  \
# 17              17      sell     apartment             Barrio El Golf
# 33              33      sell     apartment             Barrio El Golf
# 278            278      sell         house       Barrio Las Glorietas
# 416            416      sell         house           Barrio Los Lagos
# 446            446      sell         house       Barrio Las Glorietas
# 581            581      sell     apartment                      Enyoi
# 584            584      sell     apartment                      Enyoi
# 596            596      sell     apartment                 QBay Yacht
# 615            615      sell         house          Barrio La Alameda
# 616            616      sell     apartment                 QBay Yacht
# 619            619      sell     apartment            Islas del Canal
# 622            622      sell     apartment            Islas del Canal
# ...

# %%
#Eliminamos columnas no necesarias del split realizado.
df.drop(columns= (['Unnamed: 0', 'place_name', 'id', 'Country', 'State',  'Atributo6']), inplace= True)

# %%
df.head(10)
# Out:
#   operation property_type                            place_with_parent_names  \
# 0      sell            PH              |Argentina|Capital Federal|Mataderos|
# 1      sell     apartment        |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|
# 2      sell     apartment              |Argentina|Capital Federal|Mataderos|
# 3      sell            PH                |Argentina|Capital Federal|Liniers|
# 4      sell     apartment  |Argentina|Buenos Aires Costa Atlántica|Mar de...
# 5      sell         house                |Argentina|Entre Ríos|Gualeguaychú|
# 6      sell            PH  |Argentina|Bs.As. G.B.A. Zona Norte|Vicente Ló...
# 7      sell     apartment               |Argentina|Capital Federal|Belgrano|
# 8      sell     apartment               |Argentina|Capital Federal|Belgrano|
# 9      sell         house                       |Argentina|Santa Fe|Rosario|
#
#   country_name                    state_name   Municipality Localidad  \
# ...

# %%
#Reordenamos las columnas para la facilidad de su lectura.
df = df[['operation', 'property_type', 'place_with_parent_names', 'country_name', 'state_name', 'Municipality', 'Localidad', 'Neighbourhood', 'geonames_id', 'lat', 'lon', 'price', 'currency', 'price_aprox_local_currency', 'price_aprox_usd', 'surface_total_in_m2', 'surface_covered_in_m2', 'price_usd_per_m2', 'price_per_m2', 'floor', 'rooms', 'expenses', 'properati_url', 'description', 'title', 'image_thumbnail']]
df.head()
# Out:
#   operation property_type                            place_with_parent_names  \
# 0      sell            PH              |Argentina|Capital Federal|Mataderos|
# 1      sell     apartment        |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|
# 2      sell     apartment              |Argentina|Capital Federal|Mataderos|
# 3      sell            PH                |Argentina|Capital Federal|Liniers|
# 4      sell     apartment  |Argentina|Buenos Aires Costa Atlántica|Mar de...
#
#   country_name                    state_name   Municipality Localidad  \
# 0    Argentina               Capital Federal      Mataderos
# 1    Argentina        Bs.As. G.B.A. Zona Sur       La Plata
# 2    Argentina               Capital Federal      Mataderos
# 3    Argentina               Capital Federal        Liniers
# 4    Argentina  Buenos Aires Costa Atlántica  Mar del Plata    Centro
#
#   Neighbourhood  geonames_id        lat  \
# 0          None    3430787.0 -34.661824
# ...

# %%
def ambiente(i):
    for i in range(len(df['description'])):
        string = df.iloc[i]['description']
        re.finditer(r"\w+(?=\s(AMBIENTES)\b)", str(string)) 
        print(str((i.group(0)+' '+i.group(1))))

# %%
ambiente(df['description']).head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-6c4a4b926d27> in <module>()
# ----> 1 ambiente(df['description']).head()
#
# <ipython-input-20-0bb5978e7abc> in ambiente(i)
#       3         string = df.iloc[i]['description']
#       4         re.finditer(r"\w+(?=\s(AMBIENTES)\b)", str(string))
# ----> 5         print(str((i.group(0)+' '+i.group(1))))
#
# AttributeError: 'int' object has no attribute 'group'
